# %%
# Importing Pandas library

import pandas as pd

# %%
# Reading fron csv file

df = pd.read_csv('listings.csv')

# %%
#pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#                         id                                               name  \
# 0                     2539   Superfast Wi-Fi.  Clean & quiet home by the park
# 1                     2595           Skylit Midtown Manhattan Spacious Studio
# 2                     5136    Spacious Family Friendly Duplex w/ Patio + Yard
# 3                     6848                   Only 2 stops to Manhattan studio
# 4                     6872  Uptown Sanctuary w/ Private Bath (Month to Month)
# ...                    ...                                                ...
# 36317  1437489193231265423                    Charming 1 br Retreat 2 min UBS
# 36318  1437558502175065750  Blueground | Hell's Kitchen, BBQ, nr Hudson River
# 36319  1437716663281487811                      Beautiful 1-bedroom Apartment
# 36320  1437717590842865352                        Spacious Comfort Beach-Walk
# 36321  1437874319735048027                   Room in prime Hells Kitchen spot
#
# ...

# %%
# Displaying top 50 data

df.head(50)
# Out:
#        id                                               name  host_id  \
# 0    2539   Superfast Wi-Fi.  Clean & quiet home by the park     2787
# 1    2595           Skylit Midtown Manhattan Spacious Studio     2845
# 2    5136    Spacious Family Friendly Duplex w/ Patio + Yard     7378
# 3    6848                   Only 2 stops to Manhattan studio    15991
# 4    6872  Uptown Sanctuary w/ Private Bath (Month to Month)    16104
# 5    6990                            UES Beautiful Blue Room    16800
# 6    7064  Amazing location! Wburg. Large, bright & tranquil    17297
# 7    7097      Perfect for Your Parents, With Garden & Patio    17571
# 8    7801                 Sunny Williamsburg Loft with Sauna    21207
# 9    8490   Maison des Sirenes1,bohemian, luminous apartment    25183
# 10   9357                               Midtown Pied-a-terre    30193
# 11  10452                      Radiant Oasis  B&B Style room    35935
# ...

# %%
# Counting each neighbourhood group

df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        16081
# Brooklyn         13329
# Queens            5355
# Bronx             1192
# Staten Island      365
# Name: neighbourhood_group, dtype: int64

# %%
df['room_type'].value_counts()
# Out:
# Entire home/apt    19435
# Private room       16346
# Hotel room           335
# Shared room          206
# Name: room_type, dtype: int64

# %%
# Calculating median price

df['price'].median()
# Out:
# 154.0

# %%
# Finding out the type of 'last review'

type('last_review')
# Out:
# str

# %%
df.shape
# Out:
# (36322, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36322 entries, 0 to 36321
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36322 non-null  int64
#  1   name                            36320 non-null  object
#  2   host_id                         36322 non-null  int64
#  3   host_name                       36307 non-null  object
#  4   neighbourhood_group             36322 non-null  object
#  5   neighbourhood                   36322 non-null  object
#  6   latitude                        36322 non-null  float64
#  7   longitude                       36322 non-null  float64
#  8   room_type                       36322 non-null  object
#  9   price                           21459 non-null  float64
#  10  minimum_nights                  36322 non-null  int64
#  11  number_of_reviews               36322 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  3.632200e+04  3.632200e+04  36322.000000  36322.000000  21459.000000
# mean   4.382216e+17  1.713590e+08     40.728557    -73.946974    521.528356
# std    5.199100e+17  1.893709e+08      0.056482      0.055252   3501.384801
# min    2.539000e+03  1.678000e+03     40.500366    -74.251907      8.000000
# 25%    2.121091e+07  1.764159e+07     40.688282    -73.983260     89.000000
# 50%    5.004978e+07  8.336440e+07     40.725941    -73.954711    154.000000
# 75%    9.277467e+17  3.036223e+08     40.762350    -73.927853    270.000000
# max    1.444534e+18  7.005911e+08     40.911390    -73.711822  50184.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    36322.000000       36322.000000       25171.000000
# mean        29.205716          26.853037           0.817262
# std         35.111004          67.382057           1.850794
# ...

# %%
# Displying all the names

df['name']
# Out:
# 0         Superfast Wi-Fi.  Clean & quiet home by the park
# 1                 Skylit Midtown Manhattan Spacious Studio
# 2          Spacious Family Friendly Duplex w/ Patio + Yard
# 3                         Only 2 stops to Manhattan studio
# 4        Uptown Sanctuary w/ Private Bath (Month to Month)
#                                ...
# 36317                      Charming 1 br Retreat 2 min UBS
# 36318    Blueground | Hell's Kitchen, BBQ, nr Hudson River
# 36319                        Beautiful 1-bedroom Apartment
# 36320                          Spacious Comfort Beach-Walk
# 36321                     Room in prime Hells Kitchen spot
# Name: name, Length: 36322, dtype: object

# %%
df['host_name'].value_counts().head(10)
# Out:
# Blueground           1054
# Eugene                596
# Kristina              346
# Michael               341
# LuxurybookingsFZE     330
# Tina                  295
# Urban Furnished       262
# David                 260
# Hiroki                254
# Shogo                 231
# Name: host_name, dtype: int64

# %%
df['host_name']
# Out:
# 0              John
# 1          Jennifer
# 2           Rebecca
# 3             Allen
# 4         Kahshanna
#             ...
# 36317      Adetunji
# 36318    Blueground
# 36319      Charlene
# 36320       Adepeju
# 36321          Omar
# Name: host_name, Length: 36322, dtype: object

# %%
df['last_review']
# Out:
# 0        2018-10-19
# 1        2022-06-21
# 2        2023-08-20
# 3        2025-06-09
# 4        2022-06-05
#             ...
# 36317           NaN
# 36318           NaN
# 36319           NaN
# 36320           NaN
# 36321           NaN
# Name: last_review, Length: 36322, dtype: object

# %%
# Converting 'last review' to date

df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# %%
type('last_review')
# Out:
# str

# %%
# Finding earliest and latest review date

df['last_review'].min()
# Out:
# Timestamp('2011-05-12 00:00:00')

# %%
df['last_review'].max()
# Out:
# Timestamp('2025-06-17 00:00:00')

# %%
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2539   Superfast Wi-Fi.  Clean & quiet home by the park     2787
# 1  2595           Skylit Midtown Manhattan Spacious Studio     2845
# 2  5136    Spacious Family Friendly Duplex w/ Patio + Yard     7378
# 3  6848                   Only 2 stops to Manhattan studio    15991
# 4  6872  Uptown Sanctuary w/ Private Bath (Month to Month)    16104
#
#    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0       John            Brooklyn    Kensington  40.64529  -73.97238
# 1   Jennifer           Manhattan       Midtown  40.75356  -73.98559
# 2    Rebecca            Brooklyn   Sunset Park  40.66265  -73.99454
# 3      Allen            Brooklyn  Williamsburg  40.70935  -73.95342
# 4  Kahshanna           Manhattan   East Harlem  40.80107  -73.94255
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df['price'].max()
# Out:
# 50184.0

# %%
# Average price per neighbourhood group

df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx            126.100331
# Brooklyn         237.436852
# Manhattan        926.076077
# Queens           136.636499
# Staten Island    124.877358
# Name: price, dtype: float64

# %%
# Is Manhattan expensive across all room types, or just entire homes?
# Result : Expensive across all room types

grouped = df.groupby(['neighbourhood_group', 'room_type'])['price'].mean().reset_index()
grouped
# Out:
#    neighbourhood_group        room_type         price
# 0                Bronx  Entire home/apt    162.707989
# 1                Bronx     Private room    101.672794
# 2                Bronx      Shared room           NaN
# 3             Brooklyn  Entire home/apt    241.989090
# 4             Brooklyn       Hotel room  26773.133333
# 5             Brooklyn     Private room    121.384571
# 6             Brooklyn      Shared room     92.041667
# 7            Manhattan  Entire home/apt    379.454849
# 8            Manhattan       Hotel room  28486.448454
# 9            Manhattan     Private room    295.067908
# 10           Manhattan      Shared room    216.500000
# 11              Queens  Entire home/apt    191.862334
# 12              Queens       Hotel room    209.666667
# 13              Queens     Private room     94.234110
# 14              Queens      Shared room    153.970588
# 15       Staten Island  Entire home/apt    158.681529
# ...

# %%
# Using Seaborn library to plot

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.barplot(
    data=grouped,
    x='neighbourhood_group',
    y='price',
    hue='room_type'
)
plt.title('Average Price by Neighbourhood Group and Room Type')
plt.ylabel('Average Price ($)')
plt.xlabel('Neighbourhood Group')
plt.xticks(rotation=45)
plt.legend(title='Room Type')
plt.tight_layout()
#plt.ylim(0, 1000) 
plt.show()

# %%
# Grouping by neighbourhood group and price and finding out mean, max and min prices

group_neighbour = df.groupby('neighbourhood_group')['price'].agg(['mean', 'max', 'min'])
group_neighbour
# Out:
#                            mean      max   min
# neighbourhood_group
# Bronx                126.100331   9894.0  23.0
# Brooklyn             237.436852  40000.0   8.0
# Manhattan            926.076077  50184.0  10.0
# Queens               136.636499   2500.0  10.0
# Staten Island        124.877358   1400.0  25.0

# %%
# Filtering out prices below 1000

filt = df[df['price'] < 1000]

# %%
df.loc[filt]
# Out:
#                         id                                               name  \
# 0                     2539   Superfast Wi-Fi.  Clean & quiet home by the park
# 1                     2595           Skylit Midtown Manhattan Spacious Studio
# 2                     5136    Spacious Family Friendly Duplex w/ Patio + Yard
# 3                     6848                   Only 2 stops to Manhattan studio
# 5                     6990                            UES Beautiful Blue Room
# ...                    ...                                                ...
# 36317  1437489193231265423                    Charming 1 br Retreat 2 min UBS
# 36318  1437558502175065750  Blueground | Hell's Kitchen, BBQ, nr Hudson River
# 36319  1437716663281487811                      Beautiful 1-bedroom Apartment
# 36320  1437717590842865352                        Spacious Comfort Beach-Walk
# 36321  1437874319735048027                   Room in prime Hells Kitchen spot
#
# ...

# %%
group_neighbour.median()
# Out:
# mean     136.636499
# max     9894.000000
# min       10.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(data=df[df['price'] < 1000], x='neighbourhood_group', y='price')
plt.title('Price Distribution per Neighbourhood Group (Filtered)')
plt.show()
